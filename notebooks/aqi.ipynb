# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd;
from sklearn.model_selection import train_test_split;
from sklearn.ensemble import RandomForestClassifier;
import joblib;

# %% [markdown]
# ### Reading Dataset

# %%
df = pd.read_csv("../data/air_quality.csv");
print(df.head());
# Out:
#    aq  temp  humidity      label
# 0  35    26        55  Clean Air
# 1  42    27        60  Clean Air
# 2  45    28        58  Clean Air
# 3  48    29        62  Clean Air
# 4  40    27        57  Clean Air

# %%
print(df["label"].unique());
# Out:
# <StringArray>
# ['Clean Air', 'Good', 'Moderate', 'Unhealthy', 'Hazardous']
# Length: 5, dtype: str

# %% [markdown]
# ### Input and Output Features

# %%
x = df.drop("label", axis=1);
y = df["label"];

print(x.head());
print(y.head());
# Out:
#    aq  temp  humidity
# 0  35    26        55
# 1  42    27        60
# 2  45    28        58
# 3  48    29        62
# 4  40    27        57
# 0    Clean Air
# 1    Clean Air
# 2    Clean Air
# 3    Clean Air
# 4    Clean Air
# Name: label, dtype: str

# %% [markdown]
# ### Train and Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2);

# %% [markdown]
# ### Model Training

# %%
model = RandomForestClassifier(n_estimators=50);
model.fit(x_train, y_train);

# %% [markdown]
# ### Model Accuracy

# %%
print("Accuracy :", model.score(x_test, y_test));
# Out:
# Accuracy : 1.0

# %% [markdown]
# ### Saving the Model

# %%
joblib.dump(model, "model.pkl");
